# %% [markdown]
# <a href="https://colab.research.google.com/github/mounikapasumarthi/AI-ML/blob/main/python/assignments/variables_datatypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")
# Out:
# Hello world

# %%
##Create variables to store your name, age, and city. Print them.
name = input("Enter your name")
age = int(input("Enter your age"))
city = input("Enter your city")
print(name,age,city)
# Out:
# Enter your namemouni
# Enter your age23
# Enter your citymd
# mouni 23 md

# %%
##Write a program that takes your name as input and prints a greeting message.
name = input("Enter your name")
print("Hello"" "+name)

# %%
##Swap the values of two variables and print the result.
a = 12
b = 2
a = b
b = a
print("a = ",a)
print("b = ",b)

# %%
##Write a program that takes two numbers as input and prints their sum.
a = int(input("Enter the value of a"))
b = int(input("Enter the value of b"))
c = a+b
print("Sum of a,b is ",c)

# %%
#Write a program that takes a temperature in Celsius and converts it to Fahrenheit.
c = int(input("Enter the temp in celsius"))
f = (c*1.8)+32
print("Temp in fahrenheit is ",f)

# %%
##Accept a number from the user and check whether it is an integer or a float.
a = float(input("Enter your number"))
#print(type(a))
if a % 2 == 0:
  print("Integer")
else:
  print("Float")

# %%
##Take a user’s full name as input and print the number of characters (excluding spaces).
name = input("Enter your name : ".replace(" ",""))
print(name)
print(len(name))

# %%
##Write a program that takes radius as input and calculates the area and circumference of a circle.
r = int(input("Enter the radius"))
circumference = 2*3.14*r
area = 3.14*r*r
print("area of circle is : ",area)
print("circumference of the circle is : ",circumference)

# %%
##Write a program that takes a number and determines its type (int, float, complex) and whether it’s positive, negative, or zero.
a = float(input("Enter your number"))
#print(type(a))
if a == 0:
  print("Integer")
elif a > 0:
  print("it is positive integer")
